# %% [markdown]
# # LSTM Forecasting

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import RobustScaler
import numpy as np

# keras modules
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-479e875d39a9> in <module>
#       5
#       6 # keras modules
# ----> 7 from keras.models import Sequential
#       8 from keras.layers import Dense, Dropout, LSTM, Bidirectional
#
# ~/Documents/privateGit/Time-Series-Exercises/venv/lib/python3.6/site-packages/keras/__init__.py in <module>
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# ~/Documents/privateGit/Time-Series-Exercises/venv/lib/python3.6/site-packages/keras/utils/__init__.py in <module>
#       4 from . import data_utils
#       5 from . import io_utils
# ----> 6 from . import conv_utils
#       7 from . import losses_utils
#       8 from . import metrics_utils
#
# ~/Documents/privateGit/Time-Series-Exercises/venv/lib/python3.6/site-packages/keras/utils/conv_utils.py in <module>
#       7 from six.moves import range
#       8 import numpy as np
# ----> 9 from .. import backend as K
#      10
#      11
#
# ~/Documents/privateGit/Time-Series-Exercises/venv/lib/python3.6/site-packages/keras/backend/__init__.py in <module>
# ----> 1 from .load_backend import epsilon
#       2 from .load_backend import set_epsilon
#       3 from .load_backend import floatx
#       4 from .load_backend import set_floatx
#       5 from .load_backend import cast_to_floatx
#
# ~/Documents/privateGit/Time-Series-Exercises/venv/lib/python3.6/site-packages/keras/backend/load_backend.py in <module>
#      88 elif _BACKEND == 'tensorflow':
#      89     sys.stderr.write('Using TensorFlow backend.\n')
# ---> 90     from .tensorflow_backend import *
#      91 else:
#      92     # Try and load external backend.
#
# ~/Documents/privateGit/Time-Series-Exercises/venv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in <module>
#       3 from __future__ import print_function
#       4
# ----> 5 import tensorflow as tf
#       6 from tensorflow.python.eager import context
#       7 from tensorflow.python.framework import device as tfdev
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
df = pd.read_csv('data/londonBikes/london_merged.csv', parse_dates=['timestamp'])

# %%
# check schema
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
# timestamp       17414 non-null datetime64[ns]
# cnt             17414 non-null int64
# t1              17414 non-null float64
# t2              17414 non-null float64
# hum             17414 non-null float64
# wind_speed      17414 non-null float64
# weather_code    17414 non-null float64
# is_holiday      17414 non-null float64
# is_weekend      17414 non-null float64
# season          17414 non-null float64
# dtypes: datetime64[ns](1), float64(8), int64(1)
# memory usage: 1.3 MB

# %%
df.head()
# Out:
#             timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
# This data is hosted in kaggle https://www.kaggle.com/hmavrodiev/london-bike-sharing-dataset/data#
# It represents 2 yrs of data between 2015 and 2017

# %% [markdown]
# - **timestamp** - timestamp field for grouping the data
# - **cnt** - the count of a new bike shares
# - **t1** - real temperature in C
# - **t2** - temperature in C “feels like”
# - **hum** - humidity in percentage
# - **wind_speed** - wind speed in km/h
# - **weather_code** - category of the weather
# - **is_holiday** - boolean field - 1 holiday / 0 non holiday
# - **is_weekend** - boolean field - 1 if the day is weekend
# - **season** - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.

# %%
print('first timestamp:',df.timestamp[0])
print('last timestamp: ', df.timestamp.values[-1])
# Out:
# first timestamp: 2015-01-04 00:00:00
# last timestamp:  2017-01-03T23:00:00.000000000

# %% [markdown]
# # Exploration

# %%
df.set_index('timestamp', inplace=True)

# %%
# %matplotlib inline
df['cnt'].plot(figsize=(20,10))
_ = plt.ylabel('cnt')

# %% [markdown]
# It is possible to detect some kind of seasonality in the warmer months

# %%
df.resample('M').sum()['cnt'].plot(figsize=(20,10))
_ = plt.ylabel('cnt')

# %% [markdown]
# The seasonality is even more clear

# %% [markdown]
# # Feature Engineering

# %%
df['hour'] = df.index.hour
df['day_of_month'] = df.index.day
df['day_of_week'] = df.index.dayofweek
df['month'] = df.index.month

# %%
df.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season  hour  day_of_month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0     0             4
# 2015-01-04 01:00:00         0.0         1.0     3.0     1             4
# 2015-01-04 02:00:00         0.0         1.0     3.0     2             4
# 2015-01-04 03:00:00         0.0         1.0     3.0     3             4
# 2015-01-04 04:00:00         0.0         1.0     3.0     4             4
#
#                      day_of_week  month
# timestamp
# 2015-01-04 00:00:00            6      1
# 2015-01-04 01:00:00            6      1
# 2015-01-04 02:00:00            6      1
# 2015-01-04 03:00:00            6      1
# 2015-01-04 04:00:00            6      1

# %%
df_hour = df.groupby('hour').sum()

# %%
df_hour['cnt'].plot(figsize=(20,10))
_ = plt.ylabel('cnt')

# %%
df_hour_is_holiday = df.groupby(['hour', 'is_holiday']).sum()

# %%
df_hour_is_holiday = df_hour_is_holiday.reset_index()
df_hour_is_holiday.head()
# Out:
#    hour  is_holiday     cnt           t1           t2       hum   wind_speed  \
# 0     0         0.0  204836  7971.000000  7266.500000  55284.25  9859.250000
# 1     0         1.0    5565   166.500000   146.500000   1288.00   243.500000
# 2     1         0.0  141437  7784.333333  7055.833333  56118.00  9636.833333
# 3     1         1.0    3820   162.500000   142.000000   1296.50   266.000000
# 4     2         0.0   95782  7588.500000  6834.500000  56578.50  9410.000000
#
#    weather_code  is_weekend  season  day_of_month  day_of_week  month
# 0        1895.0       206.0  1058.0         11115         2148   4613
# 1          55.0         0.0    20.0           292           17    100
# 2        1986.0       206.0  1059.0         11119         2148   4617
# 3          56.0         0.0    20.0           292           17    100
# 4        2110.0       204.0  1056.0         11047         2136   4599

# %% [markdown]
# # Processing

# %%
# 90% 10% split without shufling
train_size = int(len(df) * 0.9)
test_size = len(df) - train_size
train, test = df.iloc[0:train_size], df.iloc[train_size:len(df)]
print(len(train), len(test))
# Out:
# 15672 1742

# %%
f_columns = ['t1', 't2', 'hum', 'wind_speed']

# %%
f_transformer = RobustScaler()

f_transformer = f_transformer.fit(train[f_columns].to_numpy())

train.loc[:, f_columns] = f_transformer.transform(
  train[f_columns].to_numpy()
)

test.loc[:, f_columns] = f_transformer.transform(
  test[f_columns].to_numpy()
)
# Out:
# /home/tiagocabo/.local/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/tiagocabo/.local/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# Out:
#                       cnt      t1        t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00   182 -1.2500 -1.047619  0.975   -0.818182           3.0
# 2015-01-04 01:00:00   138 -1.2500 -1.000000  0.975   -0.909091           1.0
# 2015-01-04 02:00:00   134 -1.3125 -1.000000  1.150   -1.363636           1.0
# 2015-01-04 03:00:00    72 -1.3750 -1.047619  1.325   -1.363636           1.0
# 2015-01-04 04:00:00    47 -1.3750 -1.238095  0.975   -0.772727           1.0
# 2015-01-04 05:00:00    46 -1.3750 -1.047619  0.975   -1.000000           1.0
# 2015-01-04 19:00:00         0.0         1.0     3.0    19             4
# 2015-01-04 20:00:00         0.0         1.0     3.0    20             4
# 2015-01-04 21:00:00         0.0         1.0     3.0    21             4
# 2015-01-04 22:00:00         0.0         1.0     3.0    22             4
# 2015-01-04 23:00:00         0.0         1.0     3.0    23             4
# 2015-01-05 00:00:00         0.0         0.0     3.0     0             5
# 2015-01-05 01:00:00         0.0         0.0     3.0     1             5
# 2015-01-05 02:00:00         0.0         0.0     3.0     2             5
# 2015-01-05 03:00:00         0.0         0.0     3.0     3             5
# 2015-01-05 04:00:00         0.0         0.0     3.0     4             5
# 2015-01-05 05:00:00         0.0         0.0     3.0     5             5
# ...                         ...         ...     ...   ...           ...
# 2016-10-22 02:00:00         0.0         1.0     2.0     2            22
# 2016-10-22 03:00:00         0.0         1.0     2.0     3            22
# 2016-10-22 04:00:00         0.0         1.0     2.0     4            22
# 2016-10-22 05:00:00         0.0         1.0     2.0     5            22
# 2016-10-22 06:00:00         0.0         1.0     2.0     6            22
# 2016-10-22 07:00:00         0.0         1.0     2.0     7            22
# 2016-10-22 08:00:00         0.0         1.0     2.0     8            22
# 2016-10-22 09:00:00         0.0         1.0     2.0     9            22
# 2016-10-22 10:00:00         0.0         1.0     2.0    10            22
# 2016-10-22 11:00:00         0.0         1.0     2.0    11            22
# 2016-10-22 12:00:00         0.0         1.0     2.0    12            22
# 2016-10-22 13:00:00         0.0         1.0     2.0    13            22
# 2016-10-22 14:00:00         0.0         1.0     2.0    14            22
# 2016-10-22 15:00:00         0.0         1.0     2.0    15            22
# 2016-10-22 16:00:00         0.0         1.0     2.0    16            22
# 2016-10-22 17:00:00         0.0         1.0     2.0    17            22
# 2016-10-22 18:00:00         0.0         1.0     2.0    18            22
# 2016-10-22 19:00:00         0.0         1.0     2.0    19            22
# 2016-10-22 20:00:00         0.0         1.0     2.0    20            22
# 2016-10-22 21:00:00         0.0         1.0     2.0    21            22
# 2016-10-22 22:00:00         0.0         1.0     2.0    22            22
# 2016-10-22 23:00:00         0.0         1.0     2.0    23            22
# 2016-10-23 00:00:00         0.0         1.0     2.0     0            23
# 2016-10-23 01:00:00         0.0         1.0     2.0     1            23
# 2016-10-23 02:00:00         0.0         1.0     2.0     2            23
# 2016-10-23 03:00:00         0.0         1.0     2.0     3            23
# 2016-10-23 04:00:00         0.0         1.0     2.0     4            23
# 2016-10-23 05:00:00         0.0         1.0     2.0     5            23
# 2016-10-23 06:00:00         0.0         1.0     2.0     6            23
# 2016-10-23 07:00:00         0.0         1.0     2.0     7            23
#
#                      day_of_week  month
# timestamp
# 2015-01-04 00:00:00            6      1
# 2015-01-04 01:00:00            6      1
# 2015-01-04 02:00:00            6      1
# 2015-01-04 03:00:00            6      1
# 2015-01-04 04:00:00            6      1
# 2015-01-04 05:00:00            6      1
# 2015-01-04 06:00:00            6      1
# 2015-01-04 07:00:00            6      1
# 2015-01-04 08:00:00            6      1
# 2015-01-04 09:00:00            6      1
# 2015-01-04 10:00:00            6      1
# 2015-01-04 11:00:00            6      1
# 2015-01-04 12:00:00            6      1
# 2015-01-04 13:00:00            6      1
# 2015-01-04 14:00:00            6      1
# 2015-01-04 15:00:00            6      1
# 2015-01-04 16:00:00            6      1
# 2015-01-04 17:00:00            6      1
# 2015-01-04 18:00:00            6      1
# 2015-01-04 19:00:00            6      1
# 2015-01-04 20:00:00            6      1
# 2015-01-04 21:00:00            6      1
# 2015-01-04 22:00:00            6      1
# 2015-01-04 23:00:00            6      1
# 2015-01-05 00:00:00            0      1
# 2015-01-05 01:00:00            0      1
# 2015-01-05 02:00:00            0      1
# 2015-01-05 03:00:00            0      1
# 2015-01-05 04:00:00            0      1
# 2015-01-05 05:00:00            0      1
# ...                          ...    ...
# 2016-10-22 02:00:00            5     10
# 2016-10-22 03:00:00            5     10
# 2016-10-22 04:00:00            5     10
# 2016-10-22 05:00:00            5     10
# 2016-10-22 06:00:00            5     10
# 2016-10-22 07:00:00            5     10
# 2016-10-22 08:00:00            5     10
# 2016-10-22 09:00:00            5     10
# 2016-10-22 10:00:00            5     10
# 2016-10-22 11:00:00            5     10
# 2016-10-22 12:00:00            5     10
# 2016-10-22 13:00:00            5     10
# 2016-10-22 14:00:00            5     10
# 2016-10-22 15:00:00            5     10
# 2016-10-22 16:00:00            5     10
# 2016-10-22 17:00:00            5     10
# 2016-10-22 18:00:00            5     10
# 2016-10-22 19:00:00            5     10
# 2016-10-22 20:00:00            5     10
# 2016-10-22 21:00:00            5     10
# 2016-10-22 22:00:00            5     10
# 2016-10-22 23:00:00            5     10
# 2016-10-23 00:00:00            6     10
# 2016-10-23 01:00:00            6     10
# 2016-10-23 02:00:00            6     10
# 2016-10-23 03:00:00            6     10
# 2016-10-23 04:00:00            6     10
# 2016-10-23 05:00:00            6     10
# 2016-10-23 06:00:00            6     10
# 2016-10-23 07:00:00            6     10
#
# [15672 rows x 13 columns]

# %%
# to ease the dataset preparation
def create_dataset(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        v = X.iloc[i:(i + time_steps)].values
        Xs.append(v)
        ys.append(y.iloc[i + time_steps])
    return np.array(Xs), np.array(ys)

# %%
time_steps = 10

# reshape to [samples, time_steps, n_features]

X_train, y_train = create_dataset(train, train.cnt, time_steps)
X_test, y_test = create_dataset(test, test.cnt, time_steps)

print(X_train.shape, y_train.shape)
# Out:
# (15662, 10, 13) (15662,)

# %% [markdown]
# # Apply model

# %%
X_train.shape
# Out:
# (15662, 10, 13)

# %%
# Let's start by using a bidirectional LSTM using dropout layer with adam optimizer
model = keras.Sequential()
model.add(
  keras.layers.Bidirectional(
    keras.layers.LSTM(
      units=128,
      input_shape=(X_train.shape[1], X_train.shape[2])
    )
  )
)
model.add(keras.layers.Dropout(rate=0.2))
model.add(keras.layers.Dense(units=1))
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-36a34a99b417> in <module>
#       1 # Let's start by using a bidirectional LSTM using dropout layer with adam optimizer
# ----> 2 model = keras.Sequential()
#       3 model.add(
#       4   keras.layers.Bidirectional(
#       5     keras.layers.LSTM(
#
# NameError: name 'keras' is not defined

# %%
history = model.fit(
    X_train, y_train,
    epochs=30,
    batch_size=32,
    validation_split=0.1,
    shuffle=False
)
